# %% [markdown]
# <a href="https://colab.research.google.com/github/bahadirAsilsoy/Rim-Crack-Detection-With-YOLOv8/blob/main/Cevher_Jant_%C3%87atlak_Tespit_Projesi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 22.6 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/112.6 GB disk)

# %% [markdown]
# YOLO'yu import edelim

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# Roboflow'dan gerekli olan veri setini çekelim

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="egchH4Y73wxoB1ArLk4w")
project = rf.workspace("university-bswxt").project("crack-bphdr")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Roboflowdan çektiğimiz veri setiyle eğitime başlayalım

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/crack-2/data.yaml epochs=24 imgsz=640 plots=True #yolov8s-seg.pt, yolov8s.pt segment, detect
# Out:
# /content
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Sonuçlar train klasörü içinde oluyor neyi ekrana yazdırmak istiyorsanız hangi train klasörü içinde ise ona girin yolunu kopyalayın buraya yapıştırın.

# %%
# %cd {HOME}

Image(filename=f'{HOME}/runs/segment/train2/confusion_matrix.png', width=800)
# Out:
# /content

# %%
#Image(filename=f'{HOME}/runs/detect/train/results.png', width=800)
Image(filename=f'{HOME}/runs/segment/train2/results.png', width=800)

# %%
# !yolo predict model=/content/runs/segment/train2/weights/best.pt source=/content/0RIUfPB.jpg
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11,779,987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/1 /content/0RIUfPB.jpg: 448x640 2 cracks, 52.4ms
# Speed: 3.1ms preprocess, 52.4ms inference, 688.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
